# %% [markdown]
# <h1> Hybrid Recommender Model using LightFM </h1>

# %% [markdown]
# <h3> 1. Import Libraries </h3>

# %%
from lightfm import LightFM
from lightfm.data import Dataset
import pandas as pd
import numpy as np
from sklearn.preprocessing import normalize
from sklearn.preprocessing import MultiLabelBinarizer
from scipy.sparse import csr_matrix
import pickle

# %% [markdown]
# <h3> 2. Import dataset </h3>

# %%
interactions_train  = pd.read_csv('interactions_train_new.csv',index_col=1)# read csv into ratings_df dataframe
interactions_train.drop(columns=['date','u','i','rating'],inplace=True)
interactions_train.index.names = ['id']
interactions_train.head()
# Out:
#       user_id  without_0_rating
# id
# 4684     2046               5.0
# 517      2046               5.0
# 7435     1773               5.0
# 278      1773               4.0
# 3431     2046               5.0

# %%
interactions_test  = pd.read_csv('interactions_test_new.csv')# read csv into ratings_df dataframe
interactions_test.drop(columns=['date','u','i','rating'],inplace=True)
interactions_test.head(5)
# Out:
#    user_id  recipe_id  without_0_rating
# 0     8937      44551               4.0
# 1    56680     126118               4.0
# 2   349752     219596               5.0
# 3   628951      82783               2.0
# 4    92816     435013               3.0

# %%
raw_recipes  = pd.read_csv('RAW_recipes.csv',index_col=1)# read csv into ratings_df dataframe
mask1=raw_recipes.index.isin(interactions_train.index)
#mask2=raw_recipes.index.isin(interactions_test.recipe_id)
raw_recipes=raw_recipes[mask1]
raw_recipes.shape
# Out:
# (160901, 11)

# %%
raw_recipes.head()
# Out:
#                                               name  minutes  contributor_id  \
# id
# 137739  arriba   baked winter squash mexican style       55           47892
# 31490             a bit different  breakfast pizza       30           26278
# 59389                           alouette  potatoes       45           68585
# 5289                       apple a day  milk shake        0            1533
# 70971                     bananas 4 ice cream  pie      180          102353
#
#          submitted                                               tags  \
# id
# 137739  2005-09-16  ['60-minutes-or-less', 'time-to-make', 'course...
# 31490   2002-06-17  ['30-minutes-or-less', 'time-to-make', 'course...
# 59389   2003-04-14  ['60-minutes-or-less', 'time-to-make', 'course...
# 5289    1999-12-06  ['15-minutes-or-less', 'time-to-make', 'course...
# 70971   2003-09-10  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                                 nutrition  n_steps  \
# id
# 137739              [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 31490           [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 59389           [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 5289             [160.2, 10.0, 55.0, 3.0, 9.0, 20.0, 7.0]        4
# 70971   [4270.8, 254.0, 1306.0, 111.0, 127.0, 431.0, 2...        8
#
#                                                     steps  \
# id
# 137739  ['make a choice and proceed with recipe', 'dep...
# 31490   ['preheat oven to 425 degrees f', 'press dough...
# 59389   ['place potatoes in a large pot of lightly sal...
# 5289    ['combine ingredients in blender', 'cover and ...
# 70971   ['crumble cookies into a 9-inch pie plate , or...
#
#                                               description  \
# id
# 137739  autumn is my favorite time of year to cook! th...
# 31490   this recipe calls for the crust to be prebaked...
# 59389   this is a super easy, great tasting, make ahea...
# 5289                                                  NaN
# 70971                                                 NaN
#
#                                               ingredients  n_ingredients
# id
# 137739  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 31490   ['prepared pizza crust', 'sausage patty', 'egg...              6
# 59389   ['spreadable cheese with garlic and herbs', 'n...             11
# 5289    ['milk', 'vanilla ice cream', 'frozen apple ju...              4
# 70971   ['chocolate sandwich style cookies', 'chocolat...              6

# %% [markdown]
# <h3> 3. Data Pre-processing </h3>
# <h5> a. Nutrition data</h5>
# Convert nutrition column which has data on each colorie component such as 'calories','total fat','sugar','sodium','protein','saturated fat','carbohydrates' into seperate column of its own

# %%
raw_recipes[['calories','total fat','sugar','sodium','protein','saturated fat','carbohydrates']] = raw_recipes.nutrition.str.split(",",expand=True) 
raw_recipes['calories'] = raw_recipes['calories'].apply(lambda x: x.replace("[" ,""))
raw_recipes['carbohydrates'] = raw_recipes['carbohydrates'].apply(lambda x: x.replace("]" ,""))
raw_recipes[['calories','total fat','sugar','sodium','protein','saturated fat','carbohydrates']] =  raw_recipes[['calories','total fat','sugar','sodium','protein','saturated fat','carbohydrates']].astype(float)

# %%
#drop unwanted columns
raw_recipes = raw_recipes.drop(columns=['contributor_id','nutrition', 'description','submitted'])
raw_recipes_copy  = raw_recipes
raw_recipes.head()
# Out:
#                                               name  minutes  \
# id
# 137739  arriba   baked winter squash mexican style       55
# 31490             a bit different  breakfast pizza       30
# 59389                           alouette  potatoes       45
# 5289                       apple a day  milk shake        0
# 70971                     bananas 4 ice cream  pie      180
#
#                                                      tags  n_steps  \
# id
# 137739  ['60-minutes-or-less', 'time-to-make', 'course...       11
# 31490   ['30-minutes-or-less', 'time-to-make', 'course...        9
# 59389   ['60-minutes-or-less', 'time-to-make', 'course...       11
# 5289    ['15-minutes-or-less', 'time-to-make', 'course...        4
# 70971   ['weeknight', 'time-to-make', 'course', 'main-...        8
#
#                                                     steps  \
# id
# 137739  ['make a choice and proceed with recipe', 'dep...
# 31490   ['preheat oven to 425 degrees f', 'press dough...
# 59389   ['place potatoes in a large pot of lightly sal...
# 5289    ['combine ingredients in blender', 'cover and ...
# 70971   ['crumble cookies into a 9-inch pie plate , or...
#
#                                               ingredients  n_ingredients  \
# id
# 137739  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 31490   ['prepared pizza crust', 'sausage patty', 'egg...              6
# 59389   ['spreadable cheese with garlic and herbs', 'n...             11
# 5289    ['milk', 'vanilla ice cream', 'frozen apple ju...              4
# 70971   ['chocolate sandwich style cookies', 'chocolat...              6
#
#         calories  total fat   sugar  sodium  protein  saturated fat  \
# id
# 137739      51.5        0.0    13.0     0.0      2.0            0.0
# 31490      173.4       18.0     0.0    17.0     22.0           35.0
# 59389      368.1       17.0    10.0     2.0     14.0            8.0
# 5289       160.2       10.0    55.0     3.0      9.0           20.0
# 70971     4270.8      254.0  1306.0   111.0    127.0          431.0
#
#         carbohydrates
# id
# 137739            4.0
# 31490             1.0
# 59389            20.0
# 5289              7.0
# 70971           220.0

# %% [markdown]
# <h5>b. One-hot encoding Tags list </h5>
# The tags column are in the format '60-minutes-or-less',  'time-to-make', etc. We will create a seperate column for unique tags using MultiLabelBinarizer

# %%
raw_recipes.tags.apply(lambda x: x.split(','))
# Out:
# id
# 137739    [['60-minutes-or-less',  'time-to-make',  'cou...
# 31490     [['30-minutes-or-less',  'time-to-make',  'cou...
# 59389     [['60-minutes-or-less',  'time-to-make',  'cou...
# 5289      [['15-minutes-or-less',  'time-to-make',  'cou...
# 70971     [['weeknight',  'time-to-make',  'course',  'm...
#                                 ...
# 185979    [['30-minutes-or-less',  'time-to-make',  'cou...
# 367912    [['15-minutes-or-less',  'time-to-make',  'pre...
# 357451    [['15-minutes-or-less',  'time-to-make',  'cou...
# 188810    [['60-minutes-or-less',  'time-to-make',  'cou...
# 308080    [['60-minutes-or-less',  'time-to-make',  'cou...
# Name: tags, Length: 160901, dtype: object

# %%
raw_recipes['tags']=raw_recipes['tags'].apply(eval)

# %%
mlb = MultiLabelBinarizer(sparse_output=True)
raw_recipes = raw_recipes.join(
            pd.DataFrame.sparse.from_spmatrix(
                mlb.fit_transform(raw_recipes.pop('tags')),
                index=raw_recipes.index,
                columns=mlb.classes_))

# %%
#drop unwanted columns
raw_recipes = raw_recipes.drop(columns=['steps','ingredients','','name'])

raw_recipes.head()
# Out:
#         minutes  n_steps  n_ingredients  calories  total fat   sugar  sodium  \
# id
# 137739       55       11              7      51.5        0.0    13.0     0.0
# 31490        30        9              6     173.4       18.0     0.0    17.0
# 59389        45       11             11     368.1       17.0    10.0     2.0
# 5289          0        4              4     160.2       10.0    55.0     3.0
# 70971       180        8              6    4270.8      254.0  1306.0   111.0
#
#         protein  saturated fat  carbohydrates  ...  whitefish  whole-chicken  \
# id                                             ...
# 137739      2.0            0.0            4.0  ...          0              0
# 31490      22.0           35.0            1.0  ...          0              0
# 59389      14.0            8.0           20.0  ...          0              0
# 5289        9.0           20.0            7.0  ...          0              0
# 70971     127.0          431.0          220.0  ...          0              0
#
#         whole-duck  whole-turkey  wild-game  wings  winter  \
# id
# 137739           0             0          0      0       1
# 31490            0             0          0      0       0
# 59389            0             0          0      0       0
# 5289             0             0          0      0       0
# 70971            0             0          0      0       0
#
#         yams-sweet-potatoes  yeast  zucchini
# id
# 137739                    0      0         0
# 31490                     0      0         0
# 59389                     0      0         0
# 5289                      0      0         0
# 70971                     0      0         0
#
# [5 rows x 535 columns]

# %%
raw_recipes.shape
# Out:
# (160901, 535)

# %% [markdown]
# <h3> 4. Data Preparation  </h3>
# LightFM requires the item features to have a specific format. Each recipe must be in the format (137739,['minutes:55.0','n_steps:11.0','n_ingredients:7.0','calories:51.5','total fat:0.0',]).

# %%
#helper function to identify unqiue features in the dataset
def generate_recipe_features(df):
    rf = []
    #col = ['minutes']*len(df.minutes.unique())
    col=[]
    for column in raw_recipes.columns:
        col= col+ [column]*len(df[column].unique())
    
    unique_f1=[]
    for column in df.columns:
        unique_f1=unique_f1+list(df[column].unique())
    
    unique_f1=[float(i) for i in unique_f1]
    for x,y in zip(col, unique_f1):
        res = str(x)+ ":" +str(round(y,1))
        rf.append(res)
    return rf

# %%
rf=generate_recipe_features(raw_recipes)

# %%
rf[:5]
# Out:
# ['minutes:55.0',
#  'minutes:30.0',
#  'minutes:45.0',
#  'minutes:0.0',
#  'minutes:180.0']

# %%
recipe_columns=list(raw_recipes.columns)
recipe_columns= [col+':' for col in recipe_columns]
def feature_colon_value(my_list):
   
    
    aa = my_list
    result = []
    for x,y in zip(recipe_columns,aa):
        res = str(x) +""+ str((y))
        result.append(res)
    return result

# %%
#ad_subset = raw_recipes[raw_recipes.columns]
#ad_list = [list(x) for x in ad_subset.values]

# %%
def built_item_tuples(df):
    ad_subset = df[df.columns]
    ad_list = [list(x) for x in ad_subset.values]
    feature_list = []
    for item in ad_list:
        feature_list.append(feature_colon_value(item))
    item_tuple=list(zip(df.index, feature_list))
    return item_tuple

# %%
#generate item tuples in the required format
item_tuples=built_item_tuples(raw_recipes)

# %%
item_tuples[:1]
# Out:
# [(137739,
#   ['minutes:55.0',
#    'n_steps:11.0',
#    'n_ingredients:7.0',
#    'calories:51.5',
#    'total fat:0.0',
#    'sugar:13.0',
#    'sodium:0.0',
#    'protein:2.0',
#    'saturated fat:0.0',
#    'carbohydrates:4.0',
#    '1-day-or-more:0.0',
#    '15-minutes-or-less:0.0',
#    '3-steps-or-less:0.0',
#    '30-minutes-or-less:0.0',
#    '4-hours-or-less:0.0',
#    '5-ingredients-or-less:0.0',
#    '60-minutes-or-less:1.0',
#    'Throw the ultimate fiesta with this sopaipillas recipe from Food.com.:0.0',
#    'a1-sauce:0.0',
#    'african:0.0',
#    'american:0.0',
#    'amish-mennonite:0.0',
#    'angolan:0.0',
#    'appetizers:0.0',
#    'apples:0.0',
#    'april-fools-day:0.0',
#    'argentine:0.0',
#    'artichoke:0.0',
#    'asian:0.0',
#    'asparagus:0.0',
#    'australian:0.0',
#    'austrian:0.0',
#    'avocado:0.0',
#    'bacon:0.0',
#    'baja:0.0',
#    'baked-beans:0.0',
#    'baking:0.0',
#    'bananas:0.0',
#    'bar-cookies:0.0',
#    'barbecue:0.0',
#    'bass:0.0',
#    'bean-soup:0.0',
#    'beans:0.0',
#    'beans-side-dishes:0.0',
#    'bear:0.0',
#    'beef:0.0',
#    'beef-barley-soup:0.0',
#    'beef-kidney:0.0',
#    'beef-liver:0.0',
#    'beef-organ-meats:0.0',
#    'beef-ribs:0.0',
#    'beef-sausage:0.0',
#    'beginner-cook:0.0',
#    'beijing:0.0',
#    'belgian:0.0',
#    'berries:0.0',
#    'beverages:0.0',
#    'birthday:0.0',
#    'biscotti:0.0',
#    'bisques-cream-soups:0.0',
#    'black-bean-soup:0.0',
#    'black-beans:0.0',
#    'blueberries:0.0',
#    'bok-choys:0.0',
#    'brazilian:0.0',
#    'bread-machine:0.0',
#    'bread-pudding:0.0',
#    'breads:0.0',
#    'breakfast:0.0',
#    'brewing:0.0',
#    'british-columbian:0.0',
#    'broccoli:0.0',
#    'broil:0.0',
#    'brown-bag:0.0',
#    'brown-rice:0.0',
#    'brownies:0.0',
#    'brunch:0.0',
#    'burgers:0.0',
#    'cajun:0.0',
#    'cake-fillings-and-frostings:0.0',
#    'cakes:0.0',
#    'californian:0.0',
#    'cambodian:0.0',
#    'camping:0.0',
#    'canadian:0.0',
#    'candy:0.0',
#    'canning:0.0',
#    'cantonese:0.0',
#    'caribbean:0.0',
#    'carrots:0.0',
#    'casseroles:0.0',
#    'catfish:0.0',
#    'cauliflower:0.0',
#    'celebrity:0.0',
#    'central-american:0.0',
#    'chard:0.0',
#    'cheese:0.0',
#    'cheesecake:0.0',
#    'cherries:0.0',
#    'chick-peas-garbanzos:0.0',
#    'chicken:0.0',
#    'chicken-breasts:0.0',
#    'chicken-livers:0.0',
#    'chicken-thighs-legs:0.0',
#    'chilean:0.0',
#    'chili:0.0',
#    'chinese:0.0',
#    'chinese-new-year:0.0',
#    'chocolate:0.0',
#    'chocolate-chip-cookies:0.0',
#    'chowders:0.0',
#    'christmas:1.0',
#    'chutneys:0.0',
#    'cinco-de-mayo:0.0',
#    'citrus:0.0',
#    'clams:0.0',
#    'clear-soups:0.0',
#    'cobblers-and-crisps:0.0',
#    'cocktails:0.0',
#    'coconut:0.0',
#    'cod:0.0',
#    'coffee-cakes:0.0',
#    'collard-greens:0.0',
#    'college:0.0',
#    'colombian:0.0',
#    'comfort-food:0.0',
#    'condiments-etc:0.0',
#    'congolese:0.0',
#    'cookies-and-brownies:0.0',
#    'cooking-mixes:0.0',
#    'copycat:0.0',
#    'corn:0.0',
#    'costa-rican:0.0',
#    'course:1.0',
#    'crab:0.0',
#    'crawfish:0.0',
#    'creole:0.0',
#    'crock-pot-main-dish:0.0',
#    'crock-pot-slow-cooker:0.0',
#    'crusts-pastry-dough-2:0.0',
#    'cuban:0.0',
#    'cuisine:1.0',
#    'cupcakes:0.0',
#    'curries:0.0',
#    'czech:0.0',
#    'dairy-free:0.0',
#    'danish:0.0',
#    'deep-fry:0.0',
#    'deer:0.0',
#    'dehydrator:0.0',
#    'desserts:0.0',
#    'desserts-easy:0.0',
#    'desserts-fruit:0.0',
#    'diabetic:0.0',
#    'dietary:1.0',
#    'dinner-party:0.0',
#    'dips:0.0',
#    'dips-lunch-snacks:0.0',
#    'dips-summer:0.0',
#    'drop-cookies:0.0',
#    'duck:0.0',
#    'duck-breasts:0.0',
#    'dutch:0.0',
#    'easter:0.0',
#    'easy:1.0',
#    'ecuadorean:0.0',
#    'egg-free:0.0',
#    'eggplant:0.0',
#    'eggs:0.0',
#    'eggs-dairy:0.0',
#    'egyptian:0.0',
#    'elbow-macaroni:0.0',
#    'elk:0.0',
#    'english:0.0',
#    'equipment:0.0',
#    'ethiopian:0.0',
#    'european:0.0',
#    'fall:1.0',
#    'fathers-day:0.0',
#    'filipino:0.0',
#    'fillings-and-frostings-chocolate:0.0',
#    'finger-food:0.0',
#    'finnish:0.0',
#    'fish:0.0',
#    'flat-shapes:0.0',
#    'food-processor-blender:0.0',
#    'for-1-or-2:0.0',
#    'for-large-groups:0.0',
#    'for-large-groups-holiday-event:0.0',
#    'free-of-something:0.0',
#    'freezer:0.0',
#    'french:0.0',
#    'freshwater-fish:0.0',
#    'from-scratch:0.0',
#    'frozen-desserts:0.0',
#    'fruit:0.0',
#    'fudge:0.0',
#    'garnishes:0.0',
#    'gelatin:0.0',
#    'georgian:0.0',
#    'german:0.0',
#    'gifts:0.0',
#    'gluten-free:0.0',
#    'goose:0.0',
#    'grains:0.0',
#    'granola-and-porridge:0.0',
#    'grapes:0.0',
#    'greek:0.0',
#    'green-yellow-beans:0.0',
#    'greens:0.0',
#    'grilling:0.0',
#    'ground-beef:0.0',
#    'guatemalan:0.0',
#    'gumbo:0.0',
#    'halibut:0.0',
#    'halloween:0.0',
#    'halloween-cakes:0.0',
#    'halloween-cocktails:0.0',
#    'halloween-cupcakes:0.0',
#    'ham:0.0',
#    'hand-formed-cookies:0.0',
#    'hanukkah:0.0',
#    'hawaiian:0.0',
#    'healthy:0.0',
#    'healthy-2:0.0',
#    'heirloom-historical:0.0',
#    'heirloom-historical-recipes:0.0',
#    'herb-and-spice-mixes:0.0',
#    'hidden-valley-ranch:0.0',
#    'high-calcium:0.0',
#    'high-fiber:0.0',
#    'high-in-something:0.0',
#    'high-in-something-diabetic-friendly:0.0',
#    'high-protein:0.0',
#    'holiday-event:1.0',
#    'honduran:0.0',
#    'hunan:0.0',
#    'hungarian:0.0',
#    'ice-cream:0.0',
#    'icelandic:0.0',
#    'independence-day:0.0',
#    'indian:0.0',
#    'indonesian:0.0',
#    'inexpensive:0.0',
#    'infant-baby-friendly:0.0',
#    'iranian-persian:0.0',
#    'iraqi:0.0',
#    'irish:0.0',
#    'irish-st-patricks-day:0.0',
#    'italian:0.0',
#    'jams-and-preserves:0.0',
#    'japanese:0.0',
#    'jellies:0.0',
#    'jewish-ashkenazi:0.0',
#    'jewish-sephardi:0.0',
#    'kid-friendly:0.0',
#    'kiwifruit:0.0',
#    'korean:0.0',
#    'kosher:0.0',
#    'kwanzaa:0.0',
#    'labor-day:0.0',
#    'lactose:0.0',
#    'lamb-sheep:0.0',
#    'laotian:0.0',
#    'lasagna:0.0',
#    'lebanese:0.0',
#    'leftovers:0.0',
#    'lemon:0.0',
#    'lentils:0.0',
#    'less_thansql:name_topics_of_recipegreater_than:0.0',
#    'lettuces:0.0',
#    'libyan:0.0',
#    'lime:0.0',
#    'lobster:0.0',
#    'long-grain-rice:0.0',
#    'low-calorie:0.0',
#    'low-carb:0.0',
#    'low-cholesterol:0.0',
#    'low-fat:0.0',
#    'low-in-something:0.0',
#    'low-protein:0.0',
#    'low-saturated-fat:0.0',
#    'low-sodium:0.0',
#    'lunch:0.0',
#    'macaroni-and-cheese:0.0',
#    'mahi-mahi:0.0',
#    'main-dish:0.0',
#    'main-dish-chicken:0.0',
#    'main-dish-pasta:0.0',
#    'main-dish-pork:0.0',
#    'main-ingredient:1.0',
#    'malaysian:0.0',
#    'mango:0.0',
#    'manicotti:0.0',
#    'mardi-gras-carnival:0.0',
#    'marinades-and-rubs:0.0',
#    'marinara-sauce:0.0',
#    'mashed-potatoes:0.0',
#    'meat:0.0',
#    'meatballs:0.0',
#    'meatloaf:0.0',
#    'medium-grain-rice:0.0',
#    'melons:0.0',
#    'memorial-day:0.0',
#    'mexican:1.0',
#    'micro-melanesia:0.0',
#    'microwave:0.0',
#    'middle-eastern:0.0',
#    'midwestern:0.0',
#    'mixer:0.0',
#    'mongolian:0.0',
#    'moose:0.0',
#    'moroccan:0.0',
#    'mothers-day:0.0',
#    'muffins:0.0',
#    'mushroom-soup:0.0',
#    'mushrooms:0.0',
#    'mussels:0.0',
#    'namibian:0.0',
#    'native-american:0.0',
#    'nepalese:0.0',
#    'new-years:0.0',
#    'new-zealand:0.0',
#    'nigerian:0.0',
#    'no-cook:0.0',
#    'no-shell-fish:0.0',
#    'non-alcoholic:0.0',
#    'north-american:1.0',
#    'northeastern-united-states:0.0',
#    'norwegian:0.0',
#    'novelty:0.0',
#    'number-of-servings:0.0',
#    'nut-free:0.0',
#    'nuts:0.0',
#    'oamc-freezer-make-ahead:0.0',
#    'oatmeal:0.0',
#    'oaxacan:0.0',
#    'occasion:1.0',
#    'octopus:0.0',
#    'omelets-and-frittatas:0.0',
#    'one-dish-meal:0.0',
#    'onions:0.0',
#    'ontario:0.0',
#    'orange-roughy:0.0',
#    'oranges:0.0',
#    'oven:0.0',
#    'oysters:0.0',
#    'pacific-northwest:0.0',
#    'pakistani:0.0',
#    'palestinian:0.0',
#    'pancakes-and-waffles:0.0',
#    'papaya:0.0',
#    'passover:0.0',
#    'pasta:0.0',
#    'pasta-elbow-macaroni:0.0',
#    'pasta-rice-and-grains:0.0',
#    'pasta-rice-and-grains-elbow-macaroni:0.0',
#    'pasta-salad:0.0',
#    'pasta-shells:0.0',
#    'peaches:0.0',
#    'peanut-butter:0.0',
#    'pears:0.0',
#    'penne:0.0',
#    'pennsylvania-dutch:0.0',
#    'peppers:0.0',
#    'perch:0.0',
#    'peruvian:0.0',
#    'pheasant:0.0',
#    'pickeral:0.0',
#    'picnic:0.0',
#    'pies:0.0',
#    'pies-and-tarts:0.0',
#    'pineapple:0.0',
#    'pitted-fruit:0.0',
#    'pizza:0.0',
#    'plums:0.0',
#    'polish:0.0',
#    'polynesian:0.0',
#    'pork:0.0',
#    'pork-chops:0.0',
#    'pork-crock-pot:0.0',
#    'pork-loins:0.0',
#    'pork-loins-roast:0.0',
#    'pork-ribs:0.0',
#    'pork-sausage:0.0',
#    'portuguese:0.0',
#    'pot-pie:0.0',
#    'potatoes:0.0',
#    'potluck:0.0',
#    'poultry:0.0',
#    'preparation:1.0',
#    'prepared-potatoes:0.0',
#    'presentation:0.0',
#    'pressure-canning:0.0',
#    'pressure-cooker:0.0',
#    'puddings-and-mousses:0.0',
#    'puerto-rican:0.0',
#    'pumpkin:0.0',
#    'pumpkin-bread:0.0',
#    'punch:0.0',
#    'quail:0.0',
#    'quebec:0.0',
#    'quiche:0.0',
#    'quick-breads:0.0',
#    'rabbit:0.0',
#    'ragu-recipe-contest:0.0',
#    'ramadan:0.0',
#    'raspberries:0.0',
#    'ravioli-tortellini:0.0',
#    'refrigerator:0.0',
#    'reynolds-wrap:0.0',
#    'rice:0.0',
#    'roast:0.0',
#    'roast-beef:0.0',
#    'rolled-cookies:0.0',
#    'rolls-biscuits:0.0',
#    'romantic:0.0',
#    'rosh-hashana:0.0',
#    'rosh-hashanah:0.0',
#    'russian:0.0',
#    'salad-dressings:0.0',
#    'salads:0.0',
#    'salmon:0.0',
#    'salsas:0.0',
#    'saltwater-fish:0.0',
#    'sandwiches:0.0',
#    'sauces:0.0',
#    'saudi-arabian:0.0',
#    'savory:0.0',
#    'savory-pies:0.0',
#    'savory-sauces:0.0',
#    'scallops:0.0',
#    'scandinavian:0.0',
#    'scones:0.0',
#    'scottish:0.0',
#    'seafood:0.0',
#    'seasonal:1.0',
#    'served-cold:0.0',
#    'served-hot:0.0',
#    'shakes:0.0',
#    'shellfish:0.0',
#    'short-grain-rice:0.0',
#    'shrimp:0.0',
#    'side-dishes:1.0',
#    'side-dishes-beans:0.0',
#    'simply-potatoes:0.0',
#    'simply-potatoes2:0.0',
#    'small-appliance:0.0',
#    'smoker:0.0',
#    'smoothies:0.0',
#    'snacks:0.0',
#    'sole-and-flounder:0.0',
#    'somalian:0.0',
#    'soul:0.0',
#    'soups-stews:0.0',
#    'sourdough:0.0',
#    'south-african:0.0',
#    'south-american:0.0',
#    'south-west-pacific:0.0',
#    'southern-united-states:0.0',
#    'southwestern-united-states:0.0',
#    'soy-tofu:0.0',
#    'spaghetti:0.0',
#    'spaghetti-sauce:0.0',
#    'spanish:0.0',
#    'spicy:0.0',
#    'spinach:0.0',
#    'spreads:0.0',
#    'spring:0.0',
#    'squash:1.0',
#    'squid:0.0',
#    'st-patricks-day:0.0',
#    'steak:0.0',
#    'steaks:0.0',
#    'steam:0.0',
#    'stews:0.0',
#    'stir-fry:0.0',
#    'stocks:0.0',
#    'stove-top:0.0',
#    'strawberries:0.0',
#    'stuffings-dressings:0.0',
#    'sudanese:0.0',
#    'sugar-cookies:0.0',
#    'summer:0.0',
#    'super-bowl:0.0',
#    'superbowl:0.0',
#    'swedish:0.0',
#    'sweet:0.0',
#    'sweet-sauces:0.0',
#    'swiss:0.0',
#    'szechuan:0.0',
#    'tarts:0.0',
#    'taste-mood:0.0',
#    'technique:0.0',
#    'tempeh:0.0',
#    'tex-mex:0.0',
#    'thai:0.0',
#    'thanksgiving:0.0',
#    'tilapia:0.0',
#    'time-to-make:1.0',
#    'to-go:0.0',
#    'toddler-friendly:0.0',
#    'tomatoes:0.0',
#    'tropical-fruit:0.0',
#    'trout:0.0',
#    'tuna:0.0',
#    'turkey:0.0',
#    'turkey-breasts:0.0',
#    'turkey-burgers:0.0',
#    'turkish:0.0',
#    'unprocessed-freezer:0.0',
#    'valentines-day:0.0',
#    'veal:0.0',
#    'vegan:0.0',
#    'vegetables:1.0',
#    'vegetarian:1.0',
#    'veggie-burgers:0.0',
#    'venezuelan:0.0',
#    'very-low-carbs:0.0',
#    'vietnamese:0.0',
#    'water-bath:0.0',
#    'wedding:0.0',
#    'weeknight:0.0',
#    'welsh:0.0',
#    'white-rice:0.0',
#    'whitefish:0.0',
#    'whole-chicken:0.0',
#    'whole-duck:0.0',
#    'whole-turkey:0.0',
#    'wild-game:0.0',
#    'wings:0.0',
#    'winter:1.0',
#    'yams-sweet-potatoes:0.0',
#    'yeast:0.0',
#    'zucchini:0.0'])]

# %%
#pass the unique user ID's, recipe ID's and unique item features to build the dataset
dataset1 = Dataset()
dataset1.fit(
        interactions_train['user_id'].unique(), # all the users
        interactions_train.index.unique(), # all the items
        item_features = rf # additional user features
)

# %%
item_features = dataset1.build_item_features(item_tuples, normalize= True)

# %%
item_features
# Out:
# <160901x186039 sparse matrix of type '<class 'numpy.float32'>'
# 	with 86242936 stored elements in Compressed Sparse Row format>

# %% [markdown]
# <h3> 5. Training the model </h3>

# %%
#lightfm expects the user-recipe interactions to be passed as as a CSR spare matrix
interactions_train['user_recipe_id_tuple'] = list(zip(
    interactions_train.user_id, interactions_train.index, interactions_train.without_0_rating))

# %%
interactions, weights = dataset1.build_interactions(
    interactions_train['user_recipe_id_tuple'])

# %%
model = LightFM(loss='warp',random_state=2022,
                learning_rate=0.90,
                no_components=100,
                user_alpha=0.000005)

# %%
#DO NOT RUN THIS, IT TAKES 3 HRS for COMPLETION. load the saved model from below (code below)
model.fit(interactions,item_features=item_features,epochs=5,num_threads=4,verbose=True,sample_weight=weights)
# Out:
# Epoch: 100%|███████████████████████████████████████████████████████| 5/5 [1:32:29<00:00, 1109.85s/it]

# %%
with open('lightfm_model.pickle', 'rb') as fin:
    model= pickle.load(fin)

# %%
# with open('lightfm_model.pickle', 'wb') as fle:
#     pickle.dump(model, fle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
from lightfm.evaluation import auc_score
train_auc = auc_score(model,interactions,item_features=item_features).mean()
print('Hybrid training set AUC:', train_auc)

# %%
recipe_dict=pd.DataFrame(list(interactions_train.index.unique()), columns=['recipe_id'])
user_dict=pd.DataFrame(list(interactions_train['user_id'].unique()), columns=['user_id'])
user_dict['index_val'] = user_dict.index
#scores = pd.Series(model.predict(user_id,list(recipe_dict.index.values)))

# %% [markdown]
# <h3> 6. Generate Recommendations </h3>
#
# LightFM generates implicit ratings and does not provide exact ratings in the scale of (1,5). Therefore, we cannot calculate RMSE in this case. But LightFM provides a ultility to calculate AUC and it was found to be 0.8388783 (Code in notebook LightFM_SUC.ipyb). This is a very good score.
#
# We will pass in all the available recipe ID's and the user_id as input to the LightFM model.
# LightFM ranks the recipes on its own local scale and returns the scores. We will filter out the recipes that the user has already rated from these, sort them and provide the top recommendations. The below function accomplishes all these tasks

# %%
user_dict
# Out:
#           user_id  index_val
# 0            2046          0
# 1            1773          1
# 2            2312          2
# 3            2625          3
# 4            2999          4
# ...           ...        ...
# 25071  2001355273      25071
# 25072  2002025577      25072
# 25073  2001773389      25073
# 25074  2001688000      25074
# 25075  2002312797      25075
#
# [25076 rows x 2 columns]

# %%
def user_recommendations(user_id,nrec_items=5):
    
    # LightFM requires the index of the user_id that was passed to the sparse matrix. 
    user=user_dict[user_dict['user_id']==user_id].iloc[0].index_val
    print(user_dict[user_dict['user_id']==user_id].iloc[0])
    
    user=user.item()
    
    
    #print(int(user_dict[user_dict['user_id']==user_id].iloc[0].index_val))
    #act_user_id=user_dict[user_dict['user_id']==user_id].iloc[0].index_val
    #print(act_user_id)
    
    #using the lightfm model to generate rank scores for all recipes
    scores = pd.Series(model.predict(user,list(recipe_dict.index.values)))
    
    #getting the recipes that the user has already rated
    known_items=interactions_train.loc[interactions_train.user_id == user_id]
    known_items=known_items.sort_values(by=['without_0_rating'], ascending=False)
    known_items=known_items[0:nrec_items]
    known_items = pd.merge(known_items,raw_recipes_copy,how='inner',left_on=[known_items.index],right_on=[raw_recipes_copy.index])
    
    #filtering out the recipes that the user had already rated
    scores_df=pd.DataFrame({'recipe_id':recipe_dict['recipe_id'].tolist(),
                       'score':scores
                       })
    scoremask=scores_df.recipe_id.isin(known_items.index)
    scores_df=scores_df[~(scoremask)]
    
    #sorting the recipes by highest rank
    scores_df=scores_df.sort_values(by=['score'],ascending=False)
    return_score_list=scores_df[0:nrec_items]
    return_score_list = pd.merge(return_score_list,raw_recipes_copy,how='inner',left_on=['recipe_id'],right_on=[raw_recipes_copy.index])
    
    #printing known likes
    print ("User: " + str(user_id))
    print("Known Likes:")
    counter = 1
    for index, row in known_items.iterrows():
        print(str(counter) + '- ' + row['name'])
        counter+=1
    
    #printing top recommendations
    print("\n Recommended Recipes:")
    counter = 1
    for index, row in return_score_list.iterrows():
        print(str(counter) + '- ' + row['name'])
        counter+=1

# %%
#generate the top 10 recommendation for 8937
# (6357,8937,628951)
user_id=628951
N=7
user_recommendations(user_id,N)
# Out:
# user_id      628951
# index_val     13319
# Name: 13319, dtype: int64
# User: 628951
# Known Likes:
# 1- low carb chili
# 2- chicken vegetable soup low carb low fat
# 3- herbed zucchini noodles  low fat
#
#  Recommended Recipes:
# 1- roasted cauliflower   16 roasted cloves of garlic
# 2- crock pot chicken with black beans   cream cheese
# 3- roasted tomato soup
# 4- japanese mum s chicken
# 5- tzatziki
# 6- basil pesto
# 7- kittencal s famous caesar salad

# %%
#references
#https://towardsdatascience.com/how-i-would-explain-building-lightfm-hybrid-recommenders-to-a-5-year-old-b6ee18571309
#https://towardsdatascience.com/recommendation-system-in-python-lightfm-61c85010ce17
